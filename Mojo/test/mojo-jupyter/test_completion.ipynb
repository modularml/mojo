# %%
%%test_code_completion
from std.builtin.

# %%
    # Check that we handle fully indented cells properly.
    struct Struct:
        var field_value: __mlir_type.i1

# %%
%%test_code_completion
def foo(arg: Struct):
  return arg.
